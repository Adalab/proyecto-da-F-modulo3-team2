# %%
import pandas as pd
import numpy as np
import re
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
data_set = pd.read_csv("HR RAW DATA copy.csv", index_col= 0)

# %%
df= pd.DataFrame(data_set)

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'employeecount',
#        'employeenumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NUMCOMPANIESWORKED',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TOTALWORKINGYEARS', 'TrainingTimesLastYear', 'WORKLIFEBALANCE',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YEARSWITHCURRMANAGER', 'SameAsMonthlyIncome', 'DateBirth', 'Salary',
#        'RoleDepartament', 'NUMBERCHILDREN', 'RemoteWork'],
#       dtype='object')

# %% [markdown]
# Limpiar títulos de las columnas

# %%
df.columns=df.columns.str.title()
df.columns
# Out:
# Index(['Age', 'Attrition', 'Businesstravel', 'Dailyrate', 'Department',
#        'Distancefromhome', 'Education', 'Educationfield', 'Employeecount',
#        'Employeenumber', 'Environmentsatisfaction', 'Gender', 'Hourlyrate',
#        'Jobinvolvement', 'Joblevel', 'Jobrole', 'Jobsatisfaction',
#        'Maritalstatus', 'Monthlyincome', 'Monthlyrate', 'Numcompaniesworked',
#        'Over18', 'Overtime', 'Percentsalaryhike', 'Performancerating',
#        'Relationshipsatisfaction', 'Standardhours', 'Stockoptionlevel',
#        'Totalworkingyears', 'Trainingtimeslastyear', 'Worklifebalance',
#        'Yearsatcompany', 'Yearsincurrentrole', 'Yearssincelastpromotion',
#        'Yearswithcurrmanager', 'Sameasmonthlyincome', 'Datebirth', 'Salary',
#        'Roledepartament', 'Numberchildren', 'Remotework'],
#       dtype='object')

# %%
lista=['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
       'DistanceFromHome', 'Education', 'EducationField', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
       'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
       'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 
       'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
       'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
        'TrainingTimesLastYear', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
        'SameAsMonthlyIncome', 'DateBirth', 'Salary',
       'RoleDepartament', 'RemoteWork']
# Función para agregar espacios antes de mayúsculas en medio del string
def agregar_espacios(texto):
    # Usa regex para encontrar mayúsculas en medio del string y agrega un espacio antes de ellas
    try: 
        nuevo_texto = re.sub(r'.+?[a-z](?=[A-Z]|$)|[A-Z]+$', texto)
        return nuevo_texto
    except: 
        pass

# Aplica la función a la columna del DataFrame

# %%
comosea='SameAsMonthlyIncome'
list(comosea)
# Out:
# ['S',
#  'a',
#  'm',
#  'e',
#  'A',
#  's',
#  'M',
#  'o',
#  'n',
#  't',
#  'h',
#  'l',
#  'y',
#  'I',
#  'n',
#  'c',
#  'o',
#  'm',
#  'e']

# %%
import string

# %%
string.ascii_uppercase
# Out:
# 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
string_vacio = ""
for i in list(comosea): 
    if i in string.ascii_uppercase:
        print(i)
        string_vacio =  string_vacio + " " + i
    else:
        string_vacio += i
# Out:
# S
# A
# M
# I

# %%
string_vacio.strip()
# Out:
# 'Same As Monthly Income'

# %%
for col in df.columns: 
    
    df[col]= df[col].apply(agregar_espacios)

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'employeecount',
#        'employeenumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NUMCOMPANIESWORKED',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TOTALWORKINGYEARS', 'TrainingTimesLastYear', 'WORKLIFEBALANCE',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YEARSWITHCURRMANAGER', 'SameAsMonthlyIncome', 'DateBirth', 'Salary',
#        'RoleDepartament', 'NUMBERCHILDREN', 'RemoteWork'],
#       dtype='object')

# %%
lista_guarra=['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
       'DistanceFromHome', 'Education', 'EducationField', 'employeecount',
       'employeenumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
       'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
       'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NUMCOMPANIESWORKED',
       'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
       'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
       'TOTALWORKINGYEARS', 'TrainingTimesLastYear', 'WORKLIFEBALANCE',
       'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
       'YEARSWITHCURRMANAGER', 'SameAsMonthlyIncome', 'DateBirth', 'Salary',
       'RoleDepartament', 'NUMBERCHILDREN', 'RemoteWork']

for column in lista_guarra:
    if ' ' in column:
        df[column] = df[column].apply(lambda x: x[0] + ' ' + x[1:].lower())

# %%
df
# Out:
#                Age Attrition     BusinessTravel DailyRate  \
# 0               51        No               None    684,0$
# 1               52        No               None    699,0$
# 2               42        No      travel_rarely    532,0$
# 3               47        No      travel_rarely    359,0$
# 4               46        No               None   1319,0$
# 5               48        No               None    117,0$
# 6               59        No               None   1435,0$
# 7               42        No      travel_rarely    635,0$
# 8               41        No               None   1276,0$
# 9               41        No  travel_frequently    840,0$
# 10              41        No         non-travel    247,0$
# 11              56        No      travel_rarely   1369,0$
# 12              38        No               None    201,0$
# 13              41       Yes      travel_rarely   1360,0$
# 14              55        No               None    692,0$
# 15              40        No      travel_rarely   1398,0$
# 16              58       Yes      travel_rarely    286,0$
# 17              46        No      travel_rarely   1402,0$
# 18              35        No               None    819,0$
# 19              40        No      travel_rarely    884,0$
# 20              45        No         non-travel   1238,0$
# 21              33        No               None    515,0$
# 22              36        No               None   1223,0$
# 23              47        No               None    202,0$
# 24              36        No      travel_rarely    928,0$
# 25              35        No               None    607,0$
# 26              52       Yes               None    266,0$
# 27              36        No               None    429,0$
# 28              33        No      travel_rarely    589,0$
# 29              34        No         non-travel      nan$
# 30              41        No               None      nan$
# 31     Forty-seven        No               None   1180,0$
# 32              53        No      travel_rarely   1282,0$
# 33              35        No               None    776,0$
# 34              34        No      travel_rarely    665,0$
# 35              46        No      travel_rarely    526,0$
# 36              43        No               None   1034,0$
# 37              36        No               None   1403,0$
# 38              60        No  travel_frequently   1499,0$
# 39              40        No  travel_frequently    580,0$
# 40              32        No      travel_rarely    859,0$
# 41              41        No      travel_rarely    263,0$
# 42              53        No               None   1376,0$
# 43              36       Yes      travel_rarely    885,0$
# 44              46        No               None   1003,0$
# 45              38        No      travel_rarely   1321,0$
# 46              51        No               None      nan$
# 47              43        No               None    394,0$
# 48              37        No               None   1372,0$
# 49              32        No      travel_rarely      nan$
# 50              38        No               None   1333,0$
# 51              46        No               None    228,0$
# 52              35       Yes      travel_rarely    737,0$
# 53              43        No               None    823,0$
# 54              56        No         non-travel    667,0$
# 55              36        No         non-travel    301,0$
# 56              38        No               None    573,0$
# 57              49        No               None      nan$
# 58              39        No      travel_rarely   1329,0$
# 59              40        No               None    630,0$
# 60              36        No               None      nan$
# 61              37        No               None   1063,0$
# 62              35        No               None   1017,0$
# 63              33        No  travel_frequently   1296,0$
# 64              50        No      travel_rarely    939,0$
# 65              48        No      travel_rarely   1355,0$
# 66              44        No      travel_rarely   1448,0$
# 67              44        No      travel_rarely    200,0$
# 68              40        No               None   1202,0$
# 69              34        No      travel_rarely    404,0$
# 70              35        No         non-travel    208,0$
# 71              50        No               None    813,0$
# 72              49        No               None    465,0$
# 73              38        No  travel_frequently   1189,0$
# 74              33        No               None      nan$
# 75              47        No      travel_rarely   1001,0$
# 76              38        No               None   1394,0$
# 77              37        No      travel_rarely    161,0$
# 78              30        No               None    288,0$
# 79     Fifty-eight        No      travel_rarely    682,0$
# 80              34        No      travel_rarely   1354,0$
# 81              58       Yes      travel_rarely    147,0$
# 82              38        No               None    119,0$
# 83              29        No  travel_frequently   1413,0$
# 84              55        No      travel_rarely    452,0$
# 85              41        No               None    334,0$
# 86              39        No      travel_rarely   1132,0$
# 87              38        No               None      nan$
# 88              43        No               None    982,0$
# 89              31        No               None    480,0$
# 90              50        No      travel_rarely   1099,0$
# 91              35        No               None    672,0$
# 92              47        No               None   1379,0$
# 93              35        No               None    583,0$
# 94              40        No      travel_rarely   1492,0$
# 95              45        No               None   1050,0$
# 96              33        No               None    117,0$
# 97              36        No  travel_frequently    469,0$
# 98              45       Yes               None      nan$
# 99              51        No  travel_frequently    237,0$
# 100             34        No      travel_rarely   1440,0$
# 101             43        No      travel_rarely   1291,0$
# 102             34        No               None   1157,0$
# 103             38        No               None   1336,0$
# 104             48        No               None   1224,0$
# 105             34        No               None    735,0$
# 106             32        No      travel_rarely      nan$
# 107             29        No      travel_rarely   1389,0$
# 108             46        No               None    638,0$
# 109             30        No               None   1240,0$
# 110             45        No               None    194,0$
# 111             30        No      travel_rarely   1339,0$
# 112             30        No               None    111,0$
# 113             34        No  travel_frequently      nan$
# 114             51        No      travel_rarely   1469,0$
# 115             34        No               None    470,0$
# 116             35        No      travel_rarely   1232,0$
# 117             45        No  travel_frequently   1249,0$
# 118             39        No               None    117,0$
# 119             31        No               None    798,0$
# 120             39        No               None    672,0$
# 121             45        No      travel_rarely    549,0$
# 122             30        No      travel_rarely    570,0$
# 123             31        No               None   1232,0$
# 124             36        No               None    541,0$
# 125             36        No      travel_rarely    164,0$
# 126             55        No      travel_rarely   1117,0$
# 127             35        No               None    619,0$
# 128             42        No      travel_rarely    319,0$
# 129             52        No      travel_rarely    956,0$
# 130             49        No               None   1245,0$
# 131             34        No      travel_rarely   1397,0$
# 132             33       Yes      travel_rarely    527,0$
# 133             33        No               None    213,0$
# 134             53        No      travel_rarely      nan$
# 135             49        No      travel_rarely    527,0$
# 136             35        No               None    882,0$
# 137             38        No      travel_rarely    330,0$
# 138             46        No               None    406,0$
# 139             36        No         non-travel    217,0$
# 140             42       Yes  travel_frequently    481,0$
# 141             34        No  travel_frequently    669,0$
# 142             30        No      travel_rarely   1465,0$
# 143             54        No      travel_rarely    685,0$
# 144             31        No      travel_rarely   1062,0$
# 145             44        No               None   1099,0$
# 146             55        No         non-travel    177,0$
# 147             44        No      travel_rarely   1199,0$
# 148             34        No  travel_frequently    648,0$
# 149             39        No               None    412,0$
# 150             55        No      travel_rarely    282,0$
# 151             51        No               None    770,0$
# 152             58       Yes               None    601,0$
# 153             48        No               None    855,0$
# 154             29        No      travel_rarely    332,0$
# 155             34        No               None   1326,0$
# 156             42        No  travel_frequently    748,0$
# 157             57        No      travel_rarely    405,0$
# 158             34       Yes      travel_rarely    790,0$
# 159             54        No  travel_frequently   1050,0$
# 160             34        No      travel_rarely    971,0$
# 161             29        No               None   1370,0$
# 162             35        No      travel_rarely    750,0$
# 163             35       Yes               None    880,0$
# 164             34        No      travel_rarely    678,0$
# 165             43        No               None   1179,0$
# 166             58        No         non-travel    350,0$
# 167             36        No      travel_rarely   1266,0$
# 168             43        No      travel_rarely    574,0$
# 169             55        No               None    189,0$
# 170             42        No               None      nan$
# 171             40        No               None    692,0$
# 172             56       Yes               None    310,0$
# 173             39        No      travel_rarely    722,0$
# 174             53        No      travel_rarely   1219,0$
# 175             27        No  travel_frequently    994,0$
# 176             30        No  travel_frequently    721,0$
# 177             35        No               None    853,0$
# 178             32        No      travel_rarely    427,0$
# 179             30        No      travel_rarely    852,0$
# 180             46       Yes               None    669,0$
# 181             30        No      travel_rarely   1334,0$
# 182             32        No               None   1093,0$
# 183             35        No      travel_rarely      nan$
# 184             32        No               None    967,0$
# 185             41        No      travel_rarely    465,0$
# 186             40        No      travel_rarely    989,0$
# 187             45        No               None   1195,0$
# 188             32       Yes      travel_rarely   1045,0$
# 189             30        No         non-travel    829,0$
# 190             37        No               None    663,0$
# 191             37        No               None    319,0$
# 192             40        No               None   1300,0$
# 193             36        No         non-travel   1105,0$
# 194             32        No      travel_rarely    906,0$
# 195             38        No               None    849,0$
# 196             30        No      travel_rarely   1275,0$
# 197             39        No               None   1218,0$
# 198             60        No               None    422,0$
# 199             30        No               None   1398,0$
# 200             31        No      travel_rarely   1274,0$
# 201             33       Yes               None   1076,0$
# 202             50        No               None   1207,0$
# 203             32        No               None    430,0$
# 204             42        No               None    933,0$
# 205             49       Yes               None   1184,0$
# 206             27        No               None      nan$
# 207             33        No      travel_rarely    586,0$
# 208             52        No               None    890,0$
# 209             32        No               None    379,0$
# 210             36        No               None   1425,0$
# 211             31        No         non-travel   1188,0$
# 212             36        No      travel_rarely    938,0$
# 213             52        No               None   1053,0$
# 214             33        No         non-travel    722,0$
# 215             45        No         non-travel    248,0$
# 216     Thirty-six        No      travel_rarely    796,0$
# 217             49        No               None    174,0$
# 218             29       Yes               None    408,0$
# 219             29        No               None      nan$
# 220             37        No               None    977,0$
# 221             33        No      travel_rarely    536,0$
# 222             34        No  travel_frequently    135,0$
# 223             28        No         non-travel   1476,0$
# 224             31        No         non-travel    587,0$
# 225             42        No         non-travel    495,0$
# 226             40        No      travel_rarely    523,0$
# 227             34        No               None    507,0$
# 228             58        No      travel_rarely   1055,0$
# 229             31       Yes  travel_frequently   1445,0$
# 230             40        No         non-travel    218,0$
# 231             53        No               None    447,0$
# 232             34        No               None    829,0$
# 233             35        No      travel_rarely   1029,0$
# 234             37        No               None    674,0$
# 235             42        No  travel_frequently      nan$
# 236             45        No               None    538,0$
# 237             30       Yes      travel_rarely    740,0$
# 238             38        No      travel_rarely   1245,0$
# 239             50        No               None   1234,0$
# 240             39        No      travel_rarely    170,0$
# 241             34        No      travel_rarely   1130,0$
# 242             54        No      travel_rarely    584,0$
# 243             41        No      travel_rarely    918,0$
# 244             39        No               None    792,0$
# 245             40        No      travel_rarely    611,0$
# 246             33        No               None      nan$
# 247             36        No               None   1383,0$
# 248             33        No               None    867,0$
# 249             34        No      travel_rarely      nan$
# 250             29        No  travel_frequently    574,0$
# 251             46        No      travel_rarely    706,0$
# 252             27        No      travel_rarely    728,0$
# 253             31        No               None    311,0$
# 254             45        No      travel_rarely    556,0$
# 255             34        No      travel_rarely    937,0$
# 256             31        No               None   1125,0$
# 257             35        No               None   1224,0$
# 258             39        No      travel_rarely    119,0$
# 259             40        No      travel_rarely    444,0$
# 260             30        No      travel_rarely    911,0$
# 261             47        No               None      nan$
# 262             52        No         non-travel    585,0$
# 263             49        No  travel_frequently      nan$
# 264             33        No  travel_frequently   1392,0$
# 265             32        No               None   1005,0$
# 266             38        No  travel_frequently      nan$
# 267             36        No      travel_rarely   1299,0$
# 268             42        No               None      nan$
# 269             31        No               None    655,0$
# 270             31        No      travel_rarely    746,0$
# 271             51        No               None    632,0$
# 272             34       Yes  travel_frequently    658,0$
# 273             36        No               None   1467,0$
# 274             30        No  travel_frequently   1312,0$
# 275             33        No         non-travel    750,0$
# 276             31       Yes               None    249,0$
# 277             41        No      travel_rarely    802,0$
# 278             26        No      travel_rarely   1355,0$
# 279             32        No               None    689,0$
# 280             40        No  travel_frequently   1395,0$
# 281             53        No      travel_rarely   1436,0$
# 282             29        No         non-travel   1496,0$
# 283             36        No  travel_frequently   1480,0$
# 284             33        No      travel_rarely      nan$
# 285             51        No      travel_rarely    313,0$
# 286             27        No      travel_rarely    894,0$
# 287             37        No               None    290,0$
# 288             38        No               None   1084,0$
# 289             49        No         non-travel   1002,0$
# 290             27        No               None   1242,0$
# 291             45        No               None   1052,0$
# 292             35        No               None    944,0$
# 293             33       Yes      travel_rarely    465,0$
# 294             52        No               None    771,0$
# 295             40        No               None   1416,0$
# 296             38        No         non-travel   1327,0$
# 297             46        No               None    488,0$
# 298             45        No      travel_rarely   1385,0$
# 299             47       Yes         non-travel    666,0$
# 300             35        No               None   1315,0$
# 301             29        No  travel_frequently    442,0$
# 302             55        No      travel_rarely    147,0$
# 303             26       Yes      travel_rarely    950,0$
# 304             31        No      travel_rarely    218,0$
# 305             43        No  travel_frequently      nan$
# 306             31        No      travel_rarely    691,0$
# 307             32        No               None   1018,0$
# 308             33        No               None      nan$
# 309             43        No  travel_frequently    559,0$
# 310             29       Yes      travel_rarely    318,0$
# 311             27        No               None   1130,0$
# 312             29        No      travel_rarely    144,0$
# 313             37        No               None   1319,0$
# 314             26        No      travel_rarely    933,0$
# 315             40        No      travel_rarely   1171,0$
# 316             41       Yes               None    143,0$
# 317             51        No      travel_rarely   1178,0$
# 318             37        No               None   1107,0$
# 319             56        No               None    906,0$
# 320             41        No      travel_rarely    645,0$
# 321             46        No               None   1485,0$
# 322             30        No         non-travel   1116,0$
# 323             35        No      travel_rarely   1276,0$
# 324             48        No      travel_rarely    163,0$
# 325             45        No      travel_rarely    561,0$
# 326             26       Yes  travel_frequently    426,0$
# 327             41        No               None    509,0$
# 328             34        No               None    258,0$
# 329             31        No      travel_rarely    525,0$
# 330             43        No  travel_frequently      nan$
# 331             53        No               None    238,0$
# 332             37        No      travel_rarely    482,0$
# 333             54        No               None    397,0$
# 334             38        No      travel_rarely    243,0$
# 335             29        No               None    806,0$
# 336             34        No               None   1442,0$
# 337             39        No               None    408,0$
# 338             32        No               None    929,0$
# 339             38        No      travel_rarely    827,0$
# 340             27        No      travel_rarely      nan$
# 341             32        No      travel_rarely   1018,0$
# 342             47        No               None    703,0$
# 343             27        No  travel_frequently    294,0$
# 344             41        No               None    314,0$
# 345             28       Yes               None    654,0$
# 346             36        No               None    427,0$
# 347             30        No               None    501,0$
# 348             56        No      travel_rarely      nan$
# 349             45        No      travel_rarely    954,0$
# 350             36        No         non-travel   1434,0$
# 351             29        No               None    657,0$
# 352             38        No               None    240,0$
# 353             40        No               None    791,0$
# 354             42        No  travel_frequently    570,0$
# 355             36        No      travel_rarely    676,0$
# 356             29        No      travel_rarely      nan$
# 357     Fifty-five       Yes               None    436,0$
# 358             28        No               None    760,0$
# 359             26       Yes               None      nan$
# 360             44        No               None    661,0$
# 361             41       Yes               None   1085,0$
# 362             31        No      travel_rarely    154,0$
# 363             26        No  travel_frequently   1283,0$
# 364             31        No               None    616,0$
# 365             32        No               None    498,0$
# 366             36       Yes      travel_rarely    530,0$
# 367             45        No         non-travel    805,0$
# 368             39        No      travel_rarely    903,0$
# 369             36        No         non-travel   1229,0$
# 370             46        No               None    566,0$
# 371             54        No      travel_rarely   1441,0$
# 372             30        No      travel_rarely    153,0$
# 373             26        No               None   1066,0$
# 374             55        No  travel_frequently    135,0$
# 375             50        No         non-travel    145,0$
# 376             32        No         non-travel   1109,0$
# 377             53        No  travel_frequently    124,0$
# 378             40        No      travel_rarely    300,0$
# 379             55        No               None    444,0$
# 380             28       Yes         non-travel   1366,0$
# 381             28        No      travel_rarely    857,0$
# 382             35       Yes               None   1204,0$
# 383             33       Yes  travel_frequently    827,0$
# 384             25       Yes               None   1219,0$
# 385             38        No               None    770,0$
# 386             28        No               None    950,0$
# 387             43        No  travel_frequently   1082,0$
# 388             39       Yes  travel_frequently    203,0$
# 389             40        No      travel_rarely   1308,0$
# 390             29        No      travel_rarely    718,0$
# 391             40        No               None    593,0$
# 392             26        No      travel_rarely   1384,0$
# 393             35        No      travel_rarely    819,0$
# 394             53        No               None   1223,0$
# 395             35        No               None   1361,0$
# 396             33        No               None   1146,0$
# 397             36        No               None      nan$
# 398             30        No      travel_rarely    853,0$
# 399             60        No               None      nan$
# 400             32        No               None   1316,0$
# 401             36        No               None    363,0$
# 402             27        No      travel_rarely   1103,0$
# 403             43        No               None    920,0$
# 404             29        No      travel_rarely    694,0$
# 405             59        No               None   1429,0$
# 406             43        No      travel_rarely    531,0$
# 407             44       Yes      travel_rarely    621,0$
# 408             29       Yes               None    806,0$
# 409             32        No      travel_rarely    604,0$
# 410             36        No      travel_rarely    325,0$
# 411      Fifty-two       Yes               None   1030,0$
# 412             39        No      travel_rarely    524,0$
# 413             34        No               None    943,0$
# 414             38        No               None   1009,0$
# 415             36        No  travel_frequently    607,0$
# 416             35        No               None    817,0$
# 417             55       Yes               None      nan$
# 418             34        No               None      nan$
# 419             43        No               None    930,0$
# 420             42        No      travel_rarely   1147,0$
# 421             26        No      travel_rarely    652,0$
# 422             29       Yes               None    337,0$
# 423             54        No               None    971,0$
# 424             55        No               None   1136,0$
# 425             40        No         non-travel    663,0$
# 426     Thirty-one        No               None    326,0$
# 427             46       Yes               None    377,0$
# 428             45        No      travel_rarely   1038,0$
# 429             49        No      travel_rarely   1490,0$
# 430             29        No      travel_rarely   1246,0$
# 431             29       Yes               None    224,0$
# 432             29        No               None    441,0$
# 433             40        No      travel_rarely    898,0$
# 434             48        No               None      nan$
# 435             53       Yes               None    607,0$
# 436             44        No               None   1313,0$
# 437             45        No               None   1015,0$
# 438             45        No         non-travel      nan$
# 439             34        No  travel_frequently    426,0$
# 440             39        No               None   1387,0$
# 441             27        No               None   1302,0$
# 442             45        No      travel_rarely   1329,0$
# 443             44        No               None    602,0$
# 444             25        No               None    772,0$
# 445             49        No               None    809,0$
# 446             48       Yes  travel_frequently      nan$
# 447             26        No               None    786,0$
# 448             44        No      travel_rarely    921,0$
# 449             36        No               None    530,0$
# 450             46        No               None    717,0$
# 451             35        No               None   1370,0$
# 452             30        No  travel_frequently   1312,0$
# 453             30        No               None    979,0$
# 454             33        No         non-travel   1283,0$
# 455             32        No               None    953,0$
# 456             43        No      travel_rarely    244,0$
# 457             31        No      travel_rarely    196,0$
# 458             35       Yes               None    303,0$
# 459             35        No         non-travel   1180,0$
# 460             30        No               None   1092,0$
# 461             46       Yes      travel_rarely    261,0$
# 462             45        No         non-travel    589,0$
# 463             43        No  travel_frequently   1422,0$
# 464             46       Yes               None      nan$
# 465             40        No      travel_rarely   1137,0$
# 466             27        No      travel_rarely    511,0$
# 467             42        No               None   1396,0$
# 468             26        No  travel_frequently   1096,0$
# 469             28        No  travel_frequently      nan$
# 470             47        No               None   1169,0$
# 471             34        No      travel_rarely   1239,0$
# 472             26        No               None    157,0$
# 473             27        No      travel_rarely    954,0$
# 474             31       Yes  travel_frequently    754,0$
# 475             33        No  travel_frequently   1303,0$
# 476             31        No               None    697,0$
# 477             35        No               None   1395,0$
# 478             33        No      travel_rarely    501,0$
# 479             39        No      travel_rarely    116,0$
# 480             36        No      travel_rarely    557,0$
# 481             41        No      travel_rarely    582,0$
# 482             34        No               None    704,0$
# 483             38        No      travel_rarely      nan$
# 484             39        No      travel_rarely    613,0$
# 485             34        No      travel_rarely    419,0$
# 486             44        No      travel_rarely    477,0$
# 487             46        No               None   1211,0$
# 488             41        No  travel_frequently    857,0$
# 489             39        No               None    505,0$
# 490             42        No      travel_rarely    269,0$
# 491             33        No  travel_frequently    553,0$
# 492             35        No      travel_rarely   1296,0$
# 493             33       Yes      travel_rarely   1277,0$
# 494             40        No      travel_rarely    302,0$
# 495             41        No      travel_rarely    427,0$
# 496             27        No               None    975,0$
# 497             52        No      travel_rarely    621,0$
# 498             51        No      travel_rarely   1318,0$
# 499             47        No      travel_rarely    249,0$
# 500             50        No         non-travel    881,0$
# 501             35        No      travel_rarely   1137,0$
# 502             39        No      travel_rarely    466,0$
# 503             39        No  travel_frequently    945,0$
# 504             41        No               None    509,0$
# 505             44       Yes               None   1376,0$
# 506             42        No               None    469,0$
# 507             52        No      travel_rarely    994,0$
# 508             38        No               None    433,0$
# 509             46        No               None    991,0$
# 510             35        No               None    482,0$
# 511             28        No      travel_rarely   1083,0$
# 512             44        No               None    136,0$
# 513             50        No               None    333,0$
# 514             55        No      travel_rarely    685,0$
# 515             39        No               None   1462,0$
# 516             49        No               None    722,0$
# 517             45        No               None      nan$
# 518             46        No               None   1277,0$
# 519             27        No               None   1131,0$
# 520             42        No      travel_rarely    300,0$
# 521             49        No               None   1023,0$
# 522             29        No      travel_rarely    153,0$
# 523             34        No         non-travel   1065,0$
# 524             37        No               None   1115,0$
# 525             36        No               None   1195,0$
# 526             45        No               None   1316,0$
# 527             29        No      travel_rarely    665,0$
# 528             26        No               None   1479,0$
# 529             28        No               None    304,0$
# 530             42        No  travel_frequently   1368,0$
# 531             31        No      travel_rarely    828,0$
# 532             37        No      travel_rarely    799,0$
# 533             37        No         non-travel    142,0$
# 534             37        No      travel_rarely    446,0$
# 535             24        No      travel_rarely    691,0$
# 536             50        No               None   1246,0$
# 537             34        No               None    254,0$
# 538             27        No  travel_frequently   1410,0$
# 539             25        No               None    883,0$
# 540             34        No               None    304,0$
# 541             34        No               None    121,0$
# 542             35        No               None    950,0$
# 543             35        No               None   1343,0$
# 544             33        No               None    827,0$
# 545             29        No               None   1107,0$
# 546             29        No  travel_frequently    490,0$
# 547             34        No               None   1400,0$
# 548             28        No      travel_rarely   1179,0$
# 549             44        No               None   1117,0$
# 550             31        No      travel_rarely   1332,0$
# 551             26        No               None    583,0$
# 552             47        No      travel_rarely    465,0$
# 553             37        No               None   1413,0$
# 554             32        No               None   1200,0$
# 555             32        No               None    977,0$
# 556             33        No         non-travel    530,0$
# 557             47       Yes               None   1093,0$
# 558             41       Yes               None   1102,0$
# 559             35        No      travel_rarely    809,0$
# 560             29        No      travel_rarely   1328,0$
# 561             32        No      travel_rarely    548,0$
# 562             35        No      travel_rarely   1214,0$
# 563             56        No               None      nan$
# 564             28        No               None    120,0$
# 565             25       Yes      travel_rarely    240,0$
# 566             56       Yes               None    441,0$
# 567             26        No               None    841,0$
# 568             32       Yes               None   1033,0$
# 569             30        No      travel_rarely      nan$
# 570             50        No      travel_rarely   1452,0$
# 571             32        No               None    120,0$
# 572             45        No      travel_rarely   1268,0$
# 573             43        No               None      nan$
# 574             29       Yes               None    121,0$
# 575             31        No         non-travel      nan$
# 576             33       Yes               None    813,0$
# 577             31       Yes               None    307,0$
# 578             37        No               None    228,0$
# 579             50        No               None    797,0$
# 580             42        No  travel_frequently    555,0$
# 581             27        No               None   1377,0$
# 582             27        No         non-travel    210,0$
# 583             41        No      travel_rarely    483,0$
# 584             37        No      travel_rarely    921,0$
# 585             40       Yes               None    575,0$
# 586             55        No               None   1311,0$
# 587             26       Yes  travel_frequently    575,0$
# 588             40        No      travel_rarely    759,0$
# 589             25        No               None    891,0$
# 590             30        No               None   1082,0$
# 591             52        No      travel_rarely    319,0$
# 592             42        No  travel_frequently    532,0$
# 593         Thirty        No      travel_rarely    317,0$
# 594             35        No      travel_rarely    144,0$
# 595             31        No      travel_rarely    688,0$
# 596             35        No      travel_rarely    195,0$
# 597             25        No               None    622,0$
# 598             32        No      travel_rarely    646,0$
# 599             47       Yes               None    719,0$
# 600             30        No  travel_frequently   1012,0$
# 601             45        No               None    930,0$
# 602             36        No      travel_rarely   1278,0$
# 603             31        No               None   1222,0$
# 604             37        No  travel_frequently   1231,0$
# 605             39        No      travel_rarely   1383,0$
# 606             42        No               None    462,0$
# 607             30        No      travel_rarely    231,0$
# 608             50        No               None      nan$
# 609             59        No      travel_rarely   1089,0$
# 610             54        No               None   1082,0$
# 611             56        No               None   1240,0$
# 612             48        No               None   1262,0$
# 613             39        No               None    439,0$
# 614             35        No      travel_rarely    528,0$
# 615             42        No      travel_rarely    647,0$
# 616             44       Yes               None   1097,0$
# 617             29        No      travel_rarely    942,0$
# 618             33        No               None    147,0$
# 619             54        No  travel_frequently    966,0$
# 620             46        No               None    168,0$
# 621             30        No         non-travel      nan$
# 622             32       Yes      travel_rarely   1089,0$
# 623             40       Yes               None    299,0$
# 624             34        No         non-travel    999,0$
# 625             39        No      travel_rarely   1498,0$
# 626             37        No               None   1439,0$
# 627             33        No               None   1111,0$
# 628             39        No         non-travel   1485,0$
# 629             52        No      travel_rarely    258,0$
# 630             36        No               None   1174,0$
# 631             36        No               None    172,0$
# 632             24        No      travel_rarely      nan$
# 633             34        No      travel_rarely    401,0$
# 634             28        No               None    866,0$
# 635             33        No      travel_rarely   1099,0$
# 636             47        No      travel_rarely    571,0$
# 637             40       Yes               None    676,0$
# 638             45        No      travel_rarely    950,0$
# 639             40        No      travel_rarely   1342,0$
# 640             29        No               None    995,0$
# 641             40        No               None    118,0$
# 642             43        No               None    990,0$
# 643             30        No               None    241,0$
# 644             38        No               None      nan$
# 645             37        No      travel_rarely   1470,0$
# 646             39        No      travel_rarely    492,0$
# 647             36        No      travel_rarely   1040,0$
# 648             23       Yes      travel_rarely   1320,0$
# 649             35        No               None    146,0$
# 650             31        No  travel_frequently    163,0$
# 651             38        No      travel_rarely   1153,0$
# 652             35        No               None    185,0$
# 653             40        No               None    750,0$
# 654             27        No  travel_frequently   1297,0$
# 655             41        No               None    337,0$
# 656             33        No      travel_rarely    217,0$
# 657             49        No               None   1064,0$
# 658             36        No         non-travel   1351,0$
# 659             41        No               None    930,0$
# 660             29        No               None    468,0$
# 661             31        No         non-travel      nan$
# 662             36       Yes      travel_rarely   1218,0$
# 663             43        No      travel_rarely   1273,0$
# 664             33        No  travel_frequently   1141,0$
# 665             44        No               None   1488,0$
# 666             38        No               None    653,0$
# 667             50        No               None    989,0$
# 668             59        No  travel_frequently   1225,0$
# 669             40        No  travel_frequently    530,0$
# 670             54        No      travel_rarely   1217,0$
# 671             50        No               None      nan$
# 672             54        No         non-travel    142,0$
# 673             24        No               None   1127,0$
# 674             37        No      travel_rarely   1189,0$
# 675             30        No      travel_rarely   1427,0$
# 676             34        No  travel_frequently    303,0$
# 677             57        No      travel_rarely    334,0$
# 678             38        No      travel_rarely    702,0$
# 679             41       Yes      travel_rarely      nan$
# 680             42        No               None    926,0$
# 681             34        No               None    878,0$
# 682             30       Yes               None    334,0$
# 683             29       Yes      travel_rarely    896,0$
# 684             32        No               None   1401,0$
# 685             25        No               None    675,0$
# 686             53        No               None   1070,0$
# 687             26        No               None    496,0$
# 688             28        No               None   1117,0$
# 689             28        No      travel_rarely   1476,0$
# 690             58        No               None    390,0$
# 691             27        No      travel_rarely   1220,0$
# 692             54        No  travel_frequently    928,0$
# 693             40        No      travel_rarely   1124,0$
# 694             29        No         non-travel    746,0$
# 695             50        No      travel_rarely   1046,0$
# 696             24       Yes      travel_rarely   1448,0$
# 697             30        No               None   1400,0$
# 698             34        No               None   1303,0$
# 699             33       Yes      travel_rarely    587,0$
# 700             36        No         non-travel    635,0$
# 701             41        No         non-travel    267,0$
# 702             39        No  travel_frequently    443,0$
# 703             26        No      travel_rarely    703,0$
# 704             24       Yes  travel_frequently   1287,0$
# 705             27        No               None    798,0$
# 706             27       Yes      travel_rarely   1420,0$
# 707             50       Yes               None    562,0$
# 708             23        No      travel_rarely    650,0$
# 709             39        No      travel_rarely    141,0$
# 710             52        No         non-travel    715,0$
# 711             26       Yes               None      nan$
# 712             54        No               None    376,0$
# 713             37        No      travel_rarely    571,0$
# 714             50        No      travel_rarely    691,0$
# 715             42        No               None    932,0$
# 716             38        No  travel_frequently    471,0$
# 717             25        No      travel_rarely    180,0$
# 718             32        No               None    638,0$
# 719             25        No               None    141,0$
# 720             42        No               None   1265,0$
# 721             33        No               None   1075,0$
# 722             29        No      travel_rarely   1086,0$
# 723             38        No         non-travel    152,0$
# 724             45        No      travel_rarely    974,0$
# 725             31        No  travel_frequently    853,0$
# 726             22        No               None    217,0$
# 727             59        No      travel_rarely    715,0$
# 728             45        No               None   1234,0$
# 729             45        No      travel_rarely    788,0$
# 730             37        No      travel_rarely    124,0$
# 731             26        No               None    921,0$
# 732             26        No               None    192,0$
# 733             28        No               None      nan$
# 734             24        No               None    477,0$
# 735             30        No      travel_rarely    852,0$
# 736             43       Yes               None   1372,0$
# 737             30        No      travel_rarely   1329,0$
# 738             46        No      travel_rarely    150,0$
# 739             42        No         non-travel      nan$
# 740             25        No               None      nan$
# 741             27        No               None   1167,0$
# 742             56        No      travel_rarely    206,0$
# 743             41        No  travel_frequently      nan$
# 744             28        No               None    736,0$
# 745             52        No  travel_frequently    322,0$
# 746             26        No      travel_rarely    683,0$
# 747             49       Yes  travel_frequently   1475,0$
# 748             34        No  travel_frequently    560,0$
# 749             32        No               None      nan$
# 750             33        No               None      nan$
# 751             29       Yes               None    115,0$
# 752             30        No               None      nan$
# 753             23        No               None    507,0$
# 754             33        No               None    575,0$
# 755             35        No               None      nan$
# 756             38        No  travel_frequently    888,0$
# 757             28        No               None    580,0$
# 758             37        No               None    671,0$
# 759             24        No               None    567,0$
# 760             36        No               None    311,0$
# 761             38        No  travel_frequently    148,0$
# 762             53        No      travel_rarely   1395,0$
# 763             37        No  travel_frequently   1278,0$
# 764             24        No               None    581,0$
# 765             29        No      travel_rarely   1082,0$
# 766             32        No      travel_rarely    371,0$
# 767             42        No      travel_rarely    855,0$
# 768             41        No               None    548,0$
# 769             44       Yes               None    429,0$
# 770             28        No      travel_rarely   1181,0$
# 771             39        No               None   1253,0$
# 772             40        No               None    616,0$
# 773             37       Yes      travel_rarely    370,0$
# 774             40        No               None   1194,0$
# 775             26        No      travel_rarely    572,0$
# 776             42        No               None    355,0$
# 777             34        No      travel_rarely   1480,0$
# 778             37        No      travel_rarely    783,0$
# 779             27        No               None   1354,0$
# 780             35        No      travel_rarely    682,0$
# 781             28        No         non-travel   1103,0$
# 782             29        No               None    136,0$
# 783             54        No               None    155,0$
# 784             24        No      travel_rarely    771,0$
# ...
# 725           0
# 726         Yes
# 727           0
# 728           0
# 729         Yes
# 730        True
# 731           0
# 732           1
# 733           1
# 734       False
# 735       False
# 736        True
# 737           0
# 738         Yes
# 739        True
# 740       False
# 741         Yes
# 742           0
# 743           1
# 744           1
# 745        True
# 746        True
# 747           1
# 748        True
# 749         Yes
# 750       False
# 751           0
# 752       False
# 753           0
# 754        True
# 755        True
# 756        True
# 757           1
# 758           0
# 759           0
# 760         Yes
# 761       False
# 762       False
# 763           1
# 764         Yes
# 765       False
# 766       False
# 767         Yes
# 768        True
